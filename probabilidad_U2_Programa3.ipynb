# %% [markdown]
# <a href="https://colab.research.google.com/github/fersdeivid/Unidad-2/blob/main/probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# #Probabilidad y Estadística
#
# ##Unidad 2
#
# ###Programa 3
#
# Facilitador: José Gabriel Rodriguez Rivas
#
# Alumno: Salazar Rodriguez Fernando David

# %% [markdown]
# ##Ejercicio
# 1. Existen diez asistentes de profesor disponibles para calificar exámenes en un curso de cálculo en una gran universidad.
#
# 2. El primer examen se compone de cuatro preguntas y el profesor desea seleccionar un asistente diferente para calificar cada pregunta (sólo un asistente por pregunta).
#
# 3. ¿De cuántas maneras se pueden elegir los asistentes para calificar?
#
# 4. En este caso n = tamaño del grupo = 10 y k = tamaño del subconjunto = 4.
#
# 5. El número de permutaciones es:
#
# Cn(n/r)=n!/(n-r)!
#
# Cn(n=10/r=4) = 10!/(10-4)! = 10!/6! = 3628800/720
#
# Cn = 5040

# %%
import math as mt
from itertools import permutations
from itertools import product
import numpy as np

# %%
asistentes = ["Dante", "Victoria", "Sol", "Yareli", "Kio", "Paloma", "Pablo", "Yahir", "Alexis", "Alejandro"]
n= len(asistentes)
r = 4
Pr = mt.factorial(n) / (mt.factorial(n-r))
print("Existen ", Pr," posibles permutaciones sin repetición del total de ", n," asistentes", " en grupos de ", r," en ", r)
print("Aquí las permutaciones")
permutaciones_asistentes = list(permutations (asistentes, r))
for permutacion in permutaciones_asistentes:
  print(permutacion)
# Out:
# Existen  5040.0  posibles permutaciones sin repetición del total de  10  asistentes  en grupos de  4  en  4
# Aquí las permutaciones
# ('Dante', 'Victoria', 'Sol', 'Yareli')
# ('Dante', 'Victoria', 'Sol', 'Kio')
# ('Dante', 'Victoria', 'Sol', 'Paloma')
# ('Dante', 'Victoria', 'Sol', 'Pablo')
# ('Dante', 'Victoria', 'Sol', 'Yahir')
# ('Dante', 'Victoria', 'Sol', 'Alexis')
# ('Dante', 'Victoria', 'Sol', 'Alejandro')
# ('Dante', 'Victoria', 'Yareli', 'Sol')
# ('Dante', 'Victoria', 'Yareli', 'Kio')
# ('Dante', 'Victoria', 'Yareli', 'Paloma')
# ('Dante', 'Victoria', 'Yareli', 'Pablo')
# ('Dante', 'Victoria', 'Yareli', 'Yahir')
# ('Dante', 'Victoria', 'Yareli', 'Alexis')
# ('Dante', 'Victoria', 'Yareli', 'Alejandro')
# ('Dante', 'Victoria', 'Kio', 'Sol')
# ('Dante', 'Victoria', 'Kio', 'Yareli')
# ('Dante', 'Victoria', 'Kio', 'Paloma')
# ('Dante', 'Victoria', 'Kio', 'Pablo')
# ('Dante', 'Victoria', 'Kio', 'Yahir')
# ('Dante', 'Victoria', 'Kio', 'Alexis')
# ...
